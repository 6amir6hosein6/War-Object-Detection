# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 29.88 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# %cd OIDv4_ToolKit/

# !pip3 install -r requirements.txt
# Out:
# /content/OIDv4_ToolKit
# ...
#      |████████████████████████████████| 3.3MB 2.8MB/s
# ...
#      |████████████████████████████████| 6.5MB 31.5MB/s
# ...
#   Found existing installation: rsa 4.6
#     Uninstalling rsa-4.6:
#       Successfully uninstalled rsa-4.6
#   Found existing installation: botocore 1.17.37
#     Uninstalling botocore-1.17.37:
#       Successfully uninstalled botocore-1.17.37
# ...

# %%
# !python main.py downloader --classes Tank Helicopter Boat Weapon Person --type_csv train --limit 300 --multiclasses 1
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Tank', 'Helicopter', 'Boat', 'Weapon', 'Person'] together.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...145%, 0 MB, 29139 KB/s, 0 seconds passed
# ...

# %%
# !python convert_annotations.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Tank_Helicopter_Boat_Weapon_Person
# 100% 1493/1493 [01:05<00:00, 22.65it/s]

# %%
# !rm -r OID/Dataset/train/Tank_Helicopter_Boat_Weapon_Person/Label/
# !ls OID/Dataset/train/Tank_Helicopter_Boat_Weapon_Person
# Out:
# rm: cannot remove 'OID/Dataset/train/Tank_Helicopter_Boat_Weapon_Person/Label/': No such file or directory
# 00078802fa02ba41.jpg  46f6667780685da4.jpg  a2f3c2ba48af6b39.jpg
# 00078802fa02ba41.txt  46f6667780685da4.txt  a2f3c2ba48af6b39.txt
# 001139535799c155.jpg  4715afb117f04e14.jpg  a305c13f9b5976b8.jpg
# 001139535799c155.txt  4715afb117f04e14.txt  a305c13f9b5976b8.txt
# 0012619786e2ef90.jpg  472491ae10c37c45.jpg  a31229046404edde.jpg
# 0012619786e2ef90.txt  472491ae10c37c45.txt  a31229046404edde.txt
# 0016fd7afde359f7.jpg  47277f1eba40e631.jpg  a3519aafad27c649.jpg
# 0016fd7afde359f7.txt  47277f1eba40e631.txt  a3519aafad27c649.txt
# 001cd8ae7fb68c39.jpg  47533f7e085f17ee.jpg  a354e28199a2815a.jpg
# 001cd8ae7fb68c39.txt  47533f7e085f17ee.txt  a354e28199a2815a.txt
# 0023bf87c77983ea.jpg  475bff3cabf371b1.jpg  a3567cd68406728a.jpg
# 0023bf87c77983ea.txt  475bff3cabf371b1.txt  a3567cd68406728a.txt
# 002c057f97b642ef.jpg  47859e24d0577e17.jpg  a36f707967828c09.jpg
# ...

# %%
# !cp -r 'OID/Dataset/train/Tank_Helicopter_Boat_Weapon_Person/' '/content/drive/My Drive/yolo/War Detection/obj'
